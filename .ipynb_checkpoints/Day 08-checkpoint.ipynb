# %% [markdown]
# # Advent of Code 2023, Day 8
# [Day 8 Challenge](https://adventofcode.com/2023/day/8)

# %%
import aoc
import logging
import networkx as nx
import scipy
import matplotlib
import itertools
import math
from typing import List
# %reload_ext autoreload

day = 8
sample = False

# %%
input_list = aoc.split_contents(aoc.read_input(f'Input/day_{day:02}{"_sample" if sample else ""}.txt'))

# %% [markdown]
# # Part 1

# %%
instructions = input_list[0]

# %%
nodes = dict()
for item in input_list[2:]:
    node_key = item.split('=')[0].strip()
    node_value = item.split('=')[1].replace('(','').replace(')','').replace(' ','').split(',')
    nodes[node_key] = node_value

# %%
current_node = 'AAA'
step_count = 0
while True:
    for direction in instructions:
        current_node = nodes[current_node][0] if direction == 'L' else nodes[current_node][1]
        step_count += 1
        if current_node == 'ZZZ':
            break
    if current_node == 'ZZZ':
        break

# %%
step_count
# Out:
# 20093

# %% [markdown]
# # Part 2

# %%
input_list_2 = aoc.split_contents(aoc.read_input(f'Input/day_{day:02}{"_sample_part2" if sample else ""}.txt'))

# %%
instructions = input_list_2[0]

# %%
nodes = dict()
starting_nodes = list()
for item in input_list_2[2:]:
    node_key = item.split('=')[0].strip()
    node_value = item.split('=')[1].replace('(','').replace(')','').replace(' ','').split(',')
    nodes[node_key] = node_value
    if node_key[-1] == 'A':
        starting_nodes.append(node_key)

# %%
aoc.logger.setLevel(logging.DEBUG)
start_nodes = [x for x in nodes.keys() if x[-1]=='A']
end_nodes = [x for x in nodes.keys() if x[-1]=='Z']

# %%
def get_nodes(n, step_counter, depth):
    instruction_pointer = step_counter % len(instructions)
    step_counter += 1
    next_n = list()
    for this_n in n:
        next_n.append(nodes[this_n][0] if instructions[instruction_pointer] == 'L' else nodes[this_n][1])
    check = list(set([x[-1] for x in next_n]))
    aoc.logger.info(f'{n=} {next_n=} {check=} {depth=} {instruction_pointer=} {step_counter=}')
    if len(check) > 1 or check[0] != 'Z':
        get_nodes(next_n, step_counter, depth + 1)
    return None

# %%
# get_nodes(start_nodes, 0, 0)

# %%
end_nodes
# Out:
# ['BKZ', 'KJZ', 'XNZ', 'XLZ', 'PQZ', 'ZZZ']

# %%
G = nx.MultiDiGraph()
G.add_nodes_from(list(nodes))

for key, item in nodes.items():
    aoc.logger.info(f'{item=} {key=} {item=}')
    G.add_edge(key, item[0], key='L')
    G.add_edge(key, item[1], key='R')
# Out:
# INFO:AoC:item=['XNN', 'TCJ'] key='QRX' item=['XNN', 'TCJ']
# INFO:AoC:item=['PNH', 'BVG'] key='GSM' item=['PNH', 'BVG']
# INFO:AoC:item=['VSG', 'ZZZ'] key='VDX' item=['VSG', 'ZZZ']
# INFO:AoC:item=['SHD', 'FVB'] key='TGV' item=['SHD', 'FVB']
# INFO:AoC:item=['MLX', 'CBT'] key='PPH' item=['MLX', 'CBT']
# INFO:AoC:item=['FGH', 'VLK'] key='GRP' item=['FGH', 'VLK']
# INFO:AoC:item=['TRH', 'GJX'] key='NCT' item=['TRH', 'GJX']
# INFO:AoC:item=['QHH', 'RXL'] key='TLD' item=['QHH', 'RXL']
# INFO:AoC:item=['XXT', 'XSF'] key='XMB' item=['XXT', 'XSF']
# INFO:AoC:item=['GMB', 'JGX'] key='HQP' item=['GMB', 'JGX']
# INFO:AoC:item=['BRV', 'GKL'] key='NTH' item=['BRV', 'GKL']
# INFO:AoC:item=['HJH', 'BGS'] key='RHM' item=['HJH', 'BGS']
# INFO:AoC:item=['VRX', 'XTK'] key='DPC' item=['VRX', 'XTK']
# INFO:AoC:item=['GBD', 'CCG'] key='SBD' item=['GBD', 'CCG']
# INFO:AoC:item=['CGT', 'DHB'] key='NBB' item=['CGT', 'DHB']
# INFO:AoC:item=['PPM', 'PSD'] key='GXR' item=['PPM', 'PSD']
# INFO:AoC:item=['KNV', 'STN'] key='FNR' item=['KNV', 'STN']
# INFO:AoC:item=['SBD', 'LPJ'] key='FRM' item=['SBD', 'LPJ']
# INFO:AoC:item=['SPN', 'VPX'] key='JMB' item=['SPN', 'VPX']
# INFO:AoC:item=['CBT', 'MLX'] key='RMJ' item=['CBT', 'MLX']
# INFO:AoC:item=['HPP', 'TML'] key='XXD' item=['HPP', 'TML']
# INFO:AoC:item=['LTQ', 'HKH'] key='LJQ' item=['LTQ', 'HKH']
# INFO:AoC:item=['SSL', 'SSL'] key='LJP' item=['SSL', 'SSL']
# INFO:AoC:item=['TMR', 'SJX'] key='CFM' item=['TMR', 'SJX']
# INFO:AoC:item=['TLV', 'BTH'] key='MLX' item=['TLV', 'BTH']
# INFO:AoC:item=['SPB', 'JPL'] key='LLJ' item=['SPB', 'JPL']
# INFO:AoC:item=['VLJ', 'MFX'] key='VRX' item=['VLJ', 'MFX']
# INFO:AoC:item=['GSJ', 'SMV'] key='XHM' item=['GSJ', 'SMV']
# INFO:AoC:item=['MSF', 'BKM'] key='CDQ' item=['MSF', 'BKM']
# INFO:AoC:item=['VMB', 'XND'] key='LJT' item=['VMB', 'XND']
# INFO:AoC:item=['QVQ', 'TTG'] key='DNF' item=['QVQ', 'TTG']
# INFO:AoC:item=['VGV', 'FJC'] key='BLB' item=['VGV', 'FJC']
# INFO:AoC:item=['HBS', 'DTS'] key='FXK' item=['HBS', 'DTS']
# INFO:AoC:item=['PGC', 'GSB'] key='VDT' item=['PGC', 'GSB']
# INFO:AoC:item=['QXK', 'GFC'] key='GFS' item=['QXK', 'GFC']
# INFO:AoC:item=['LVX', 'LKD'] key='LGT' item=['LVX', 'LKD']
# INFO:AoC:item=['RXB', 'XXR'] key='XRJ' item=['RXB', 'XXR']
# INFO:AoC:item=['RFK', 'TMX'] key='GRT' item=['RFK', 'TMX']
# INFO:AoC:item=['QBQ', 'HPH'] key='HLK' item=['QBQ', 'HPH']
# INFO:AoC:item=['LBL', 'XXD'] key='SCK' item=['LBL', 'XXD']
# INFO:AoC:item=['TLD', 'RJD'] key='LMR' item=['TLD', 'RJD']
# INFO:AoC:item=['XNX', 'MXV'] key='BRP' item=['XNX', 'MXV']
# INFO:AoC:item=['NRD', 'JRP'] key='CVV' item=['NRD', 'JRP']
# INFO:AoC:item=['BRV', 'GKL'] key='VPH' item=['BRV', 'GKL']
# INFO:AoC:item=['NQC', 'QNV'] key='XSD' item=['NQC', 'QNV']
# INFO:AoC:item=['QPQ', 'PJJ'] key='BPT' item=['QPQ', 'PJJ']
# INFO:AoC:item=['GPB', 'RQG'] key='SQG' item=['GPB', 'RQG']
# INFO:AoC:item=['VTV', 'HXR'] key='SXL' item=['VTV', 'HXR']
# INFO:AoC:item=['DVX', 'DGL'] key='FMG' item=['DVX', 'DGL']
# INFO:AoC:item=['LTJ', 'LTJ'] key='JQF' item=['LTJ', 'LTJ']
# INFO:AoC:item=['BPC', 'VBM'] key='HHC' item=['BPC', 'VBM']
# INFO:AoC:item=['DLL', 'KRC'] key='TFJ' item=['DLL', 'KRC']
# INFO:AoC:item=['XDK', 'HXS'] key='QTM' item=['XDK', 'HXS']
# INFO:AoC:item=['GHX', 'CSL'] key='HBV' item=['GHX', 'CSL']
# INFO:AoC:item=['PJS', 'JNQ'] key='HXS' item=['PJS', 'JNQ']
# INFO:AoC:item=['JGQ', 'NHL'] key='TTG' item=['JGQ', 'NHL']
# INFO:AoC:item=['LDJ', 'KSP'] key='FQN' item=['LDJ', 'KSP']
# INFO:AoC:item=['CFK', 'TCL'] key='NND' item=['CFK', 'TCL']
# INFO:AoC:item=['NGP', 'XMP'] key='DGP' item=['NGP', 'XMP']
# INFO:AoC:item=['QKR', 'HFM'] key='FSN' item=['QKR', 'HFM']
# INFO:AoC:item=['SRF', 'PBL'] key='FDG' item=['SRF', 'PBL']
# INFO:AoC:item=['LRX', 'CLT'] key='PFN' item=['LRX', 'CLT']
# INFO:AoC:item=['TCV', 'SPP'] key='VSX' item=['TCV', 'SPP']
# INFO:AoC:item=['CVR', 'SJM'] key='GRB' item=['CVR', 'SJM']
# INFO:AoC:item=['JRJ', 'SCX'] key='JXP' item=['JRJ', 'SCX']
# INFO:AoC:item=['BGR', 'DRD'] key='DTF' item=['BGR', 'DRD']
# INFO:AoC:item=['DFQ', 'LVC'] key='JPL' item=['DFQ', 'LVC']
# INFO:AoC:item=['RKH', 'BKZ'] key='HKJ' item=['RKH', 'BKZ']
# INFO:AoC:item=['PMT', 'PMT'] key='TRQ' item=['PMT', 'PMT']
# INFO:AoC:item=['TVL', 'HRP'] key='KTG' item=['TVL', 'HRP']
# INFO:AoC:item=['PSG', 'FXX'] key='LFM' item=['PSG', 'FXX']
# INFO:AoC:item=['FHT', 'NVG'] key='FHK' item=['FHT', 'NVG']
# INFO:AoC:item=['QFB', 'GHT'] key='FTD' item=['QFB', 'GHT']
# INFO:AoC:item=['NGD', 'LDC'] key='SKX' item=['NGD', 'LDC']
# INFO:AoC:item=['GMB', 'JGX'] key='XTB' item=['GMB', 'JGX']
# INFO:AoC:item=['TVL', 'HRP'] key='CQK' item=['TVL', 'HRP']
# INFO:AoC:item=['GDF', 'SCN'] key='NRD' item=['GDF', 'SCN']
# INFO:AoC:item=['SFQ', 'VLX'] key='GBD' item=['SFQ', 'VLX']
# INFO:AoC:item=['SNQ', 'MDX'] key='GTP' item=['SNQ', 'MDX']
# INFO:AoC:item=['JVS', 'XSK'] key='PDT' item=['JVS', 'XSK']
# INFO:AoC:item=['GFS', 'NSS'] key='QRJ' item=['GFS', 'NSS']
# INFO:AoC:item=['JDV', 'THC'] key='SXD' item=['JDV', 'THC']
# INFO:AoC:item=['NPR', 'BGX'] key='TCR' item=['NPR', 'BGX']
# INFO:AoC:item=['LPL', 'HGH'] key='DGL' item=['LPL', 'HGH']
# INFO:AoC:item=['JSB', 'FMG'] key='SHQ' item=['JSB', 'FMG']
# INFO:AoC:item=['VBJ', 'RFJ'] key='BKZ' item=['VBJ', 'RFJ']
# INFO:AoC:item=['BQV', 'QGT'] key='LVX' item=['BQV', 'QGT']
# INFO:AoC:item=['PGC', 'GSB'] key='SRH' item=['PGC', 'GSB']
# INFO:AoC:item=['FQX', 'DCN'] key='KJR' item=['FQX', 'DCN']
# INFO:AoC:item=['JVB', 'BDB'] key='PGV' item=['JVB', 'BDB']
# INFO:AoC:item=['LFM', 'CSX'] key='BVG' item=['LFM', 'CSX']
# INFO:AoC:item=['BMV', 'LLS'] key='KDJ' item=['BMV', 'LLS']
# INFO:AoC:item=['DSF', 'CDL'] key='JNX' item=['DSF', 'CDL']
# INFO:AoC:item=['TKL', 'TQX'] key='QGT' item=['TKL', 'TQX']
# INFO:AoC:item=['VDM', 'VND'] key='PKK' item=['VDM', 'VND']
# INFO:AoC:item=['TGG', 'XCD'] key='DHS' item=['TGG', 'XCD']
# INFO:AoC:item=['QGT', 'BQV'] key='LKD' item=['QGT', 'BQV']
# INFO:AoC:item=['JQF', 'RXQ'] key='HGH' item=['JQF', 'RXQ']
# INFO:AoC:item=['SHQ', 'RGG'] key='GCK' item=['SHQ', 'RGG']
# INFO:AoC:item=['HNF', 'NMR'] key='JCQ' item=['HNF', 'NMR']
# INFO:AoC:item=['TRK', 'KPK'] key='XMT' item=['TRK', 'KPK']
# INFO:AoC:item=['HKV', 'HKV'] key='CJC' item=['HKV', 'HKV']
# INFO:AoC:item=['QBQ', 'HPH'] key='XFM' item=['QBQ', 'HPH']
# INFO:AoC:item=['LKT', 'SCK'] key='BRQ' item=['LKT', 'SCK']
# INFO:AoC:item=['XHV', 'KDJ'] key='VSG' item=['XHV', 'KDJ']
# INFO:AoC:item=['BDR', 'JNC'] key='GSJ' item=['BDR', 'JNC']
# INFO:AoC:item=['TSD', 'BGM'] key='CXJ' item=['TSD', 'BGM']
# INFO:AoC:item=['PKH', 'SQB'] key='RJX' item=['PKH', 'SQB']
# INFO:AoC:item=['DJF', 'RRR'] key='HMN' item=['DJF', 'RRR']
# INFO:AoC:item=['GXV', 'SQG'] key='TKL' item=['GXV', 'SQG']
# INFO:AoC:item=['FKN', 'XPL'] key='QVJ' item=['FKN', 'XPL']
# INFO:AoC:item=['TLR', 'CGG'] key='CLT' item=['TLR', 'CGG']
# INFO:AoC:item=['NXB', 'KPC'] key='HPP' item=['NXB', 'KPC']
# INFO:AoC:item=['JSB', 'FMG'] key='RGG' item=['JSB', 'FMG']
# INFO:AoC:item=['LPJ', 'SBD'] key='VQC' item=['LPJ', 'SBD']
# INFO:AoC:item=['PJJ', 'QPQ'] key='FQL' item=['PJJ', 'QPQ']
# INFO:AoC:item=['KJR', 'HMS'] key='QKR' item=['KJR', 'HMS']
# INFO:AoC:item=['PKN', 'KLG'] key='RFK' item=['PKN', 'KLG']
# INFO:AoC:item=['HRG', 'HRG'] key='QDH' item=['HRG', 'HRG']
# INFO:AoC:item=['LHV', 'PCM'] key='KKG' item=['LHV', 'PCM']
# INFO:AoC:item=['NDM', 'XXM'] key='PBF' item=['NDM', 'XXM']
# INFO:AoC:item=['NDM', 'XXM'] key='XVG' item=['NDM', 'XXM']
# INFO:AoC:item=['HMN', 'RLL'] key='BGX' item=['HMN', 'RLL']
# INFO:AoC:item=['XXR', 'RXB'] key='DKL' item=['XXR', 'RXB']
# INFO:AoC:item=['CJM', 'GSM'] key='MFK' item=['CJM', 'GSM']
# INFO:AoC:item=['CKC', 'VKB'] key='JLP' item=['CKC', 'VKB']
# INFO:AoC:item=['TCR', 'BBD'] key='TSD' item=['TCR', 'BBD']
# INFO:AoC:item=['CQK', 'KTG'] key='KLG' item=['CQK', 'KTG']
# INFO:AoC:item=['NQG', 'CDF'] key='XCD' item=['NQG', 'CDF']
# INFO:AoC:item=['JXH', 'BTG'] key='HXR' item=['JXH', 'BTG']
# INFO:AoC:item=['PQL', 'MBC'] key='FQH' item=['PQL', 'MBC']
# INFO:AoC:item=['TXL', 'LCP'] key='HBS' item=['TXL', 'LCP']
# INFO:AoC:item=['TFJ', 'JDN'] key='DCV' item=['TFJ', 'JDN']
# INFO:AoC:item=['PCV', 'MBQ'] key='QDK' item=['PCV', 'MBQ']
# INFO:AoC:item=['QDK', 'XHH'] key='LDJ' item=['QDK', 'XHH']
# INFO:AoC:item=['NXX', 'BNL'] key='HHB' item=['NXX', 'BNL']
# INFO:AoC:item=['MDJ', 'HDC'] key='SCH' item=['MDJ', 'HDC']
# INFO:AoC:item=['MDN', 'HTD'] key='BBJ' item=['MDN', 'HTD']
# INFO:AoC:item=['QVJ', 'KLR'] key='BGL' item=['QVJ', 'KLR']
# INFO:AoC:item=['MTQ', 'LPH'] key='VBF' item=['MTQ', 'LPH']
# INFO:AoC:item=['VLK', 'FGH'] key='CQG' item=['VLK', 'FGH']
# INFO:AoC:item=['JRN', 'JPB'] key='PQH' item=['JRN', 'JPB']
# INFO:AoC:item=['HHR', 'LFH'] key='VGV' item=['HHR', 'LFH']
# INFO:AoC:item=['XFQ', 'GCK'] key='CRK' item=['XFQ', 'GCK']
# INFO:AoC:item=['RKX', 'VBF'] key='VVX' item=['RKX', 'VBF']
# INFO:AoC:item=['FHF', 'BJP'] key='GDF' item=['FHF', 'BJP']
# INFO:AoC:item=['MSF', 'BKM'] key='LHF' item=['MSF', 'BKM']
# INFO:AoC:item=['VMX', 'RCD'] key='MBQ' item=['VMX', 'RCD']
# INFO:AoC:item=['NMC', 'RRN'] key='JRJ' item=['NMC', 'RRN']
# INFO:AoC:item=['NVQ', 'RJX'] key='CFD' item=['NVQ', 'RJX']
# INFO:AoC:item=['MPD', 'VNN'] key='MPB' item=['MPD', 'VNN']
# INFO:AoC:item=['SJB', 'CFM'] key='JPQ' item=['SJB', 'CFM']
# INFO:AoC:item=['KLR', 'QVJ'] key='NCB' item=['KLR', 'QVJ']
# INFO:AoC:item=['PDT', 'VNP'] key='CVR' item=['PDT', 'VNP']
# INFO:AoC:item=['JKG', 'BBS'] key='QGF' item=['JKG', 'BBS']
# INFO:AoC:item=['FSN', 'KJZ'] key='KCG' item=['FSN', 'KJZ']
# INFO:AoC:item=['QXX', 'JSG'] key='DRD' item=['QXX', 'JSG']
# INFO:AoC:item=['SRH', 'VDT'] key='TCV' item=['SRH', 'VDT']
# INFO:AoC:item=['KKG', 'TFR'] key='QRM' item=['KKG', 'TFR']
# INFO:AoC:item=['KDG', 'PNT'] key='GNX' item=['KDG', 'PNT']
# INFO:AoC:item=['LJQ', 'RNN'] key='KBM' item=['LJQ', 'RNN']
# INFO:AoC:item=['QSG', 'DGN'] key='GDT' item=['QSG', 'DGN']
# INFO:AoC:item=['VVX', 'LXP'] key='HJH' item=['VVX', 'LXP']
# INFO:AoC:item=['MKQ', 'GRF'] key='GSB' item=['MKQ', 'GRF']
# INFO:AoC:item=['PLD', 'CXJ'] key='CVG' item=['PLD', 'CXJ']
# INFO:AoC:item=['DNX', 'DBM'] key='QJK' item=['DNX', 'DBM']
# INFO:AoC:item=['XVG', 'PBF'] key='DDX' item=['XVG', 'PBF']
# INFO:AoC:item=['XSD', 'TJF'] key='DBM' item=['XSD', 'TJF']
# INFO:AoC:item=['GJM', 'VFJ'] key='NGP' item=['GJM', 'VFJ']
# INFO:AoC:item=['RQX', 'BSG'] key='FFF' item=['RQX', 'BSG']
# INFO:AoC:item=['BNL', 'NXX'] key='VXH' item=['BNL', 'NXX']
# INFO:AoC:item=['PCL', 'NBK'] key='GTQ' item=['PCL', 'NBK']
# INFO:AoC:item=['XPK', 'RTX'] key='NDM' item=['XPK', 'RTX']
# INFO:AoC:item=['KCM', 'FTD'] key='BPC' item=['KCM', 'FTD']
# INFO:AoC:item=['CMS', 'HTJ'] key='GVJ' item=['CMS', 'HTJ']
# INFO:AoC:item=['NXB', 'KPC'] key='TML' item=['NXB', 'KPC']
# INFO:AoC:item=['DFQ', 'LVC'] key='SPB' item=['DFQ', 'LVC']
# INFO:AoC:item=['JNC', 'BDR'] key='SMV' item=['JNC', 'BDR']
# INFO:AoC:item=['KGB', 'JRC'] key='PBG' item=['KGB', 'JRC']
# INFO:AoC:item=['HHC', 'LXT'] key='JGF' item=['HHC', 'LXT']
# INFO:AoC:item=['GVQ', 'BXG'] key='VXF' item=['GVQ', 'BXG']
# INFO:AoC:item=['XKB', 'XDL'] key='PRL' item=['XKB', 'XDL']
# INFO:AoC:item=['QTM', 'MPN'] key='TXL' item=['QTM', 'MPN']
# INFO:AoC:item=['JVB', 'BDB'] key='FHP' item=['JVB', 'BDB']
# INFO:AoC:item=['PGV', 'FHP'] key='FXX' item=['PGV', 'FHP']
# INFO:AoC:item=['XFQ', 'GCK'] key='QPD' item=['XFQ', 'GCK']
# INFO:AoC:item=['VSX', 'MCT'] key='PKH' item=['VSX', 'MCT']
# INFO:AoC:item=['GBR', 'MBR'] key='VLX' item=['GBR', 'MBR']
# INFO:AoC:item=['LJT', 'DKB'] key='MXV' item=['LJT', 'DKB']
# INFO:AoC:item=['FTM', 'XGT'] key='QPQ' item=['FTM', 'XGT']
# INFO:AoC:item=['QRJ', 'SGV'] key='PMB' item=['QRJ', 'SGV']
# INFO:AoC:item=['CQR', 'CRB'] key='DJF' item=['CQR', 'CRB']
# INFO:AoC:item=['RHM', 'HGD'] key='MRV' item=['RHM', 'HGD']
# INFO:AoC:item=['GRB', 'NSJ'] key='SBT' item=['GRB', 'NSJ']
# INFO:AoC:item=['QPS', 'KSG'] key='PRT' item=['QPS', 'KSG']
# INFO:AoC:item=['FQX', 'DCN'] key='HMS' item=['FQX', 'DCN']
# INFO:AoC:item=['XMT', 'TDJ'] key='QFF' item=['XMT', 'TDJ']
# INFO:AoC:item=['CMS', 'HTJ'] key='KVB' item=['CMS', 'HTJ']
# INFO:AoC:item=['MHV', 'GDT'] key='GJM' item=['MHV', 'GDT']
# INFO:AoC:item=['MXN', 'DRG'] key='BRX' item=['MXN', 'DRG']
# INFO:AoC:item=['DNX', 'DBM'] key='CFL' item=['DNX', 'DBM']
# INFO:AoC:item=['QGF', 'MRL'] key='VGA' item=['QGF', 'MRL']
# INFO:AoC:item=['RLF', 'MBT'] key='GFQ' item=['RLF', 'MBT']
# INFO:AoC:item=['MLL', 'RDP'] key='LVJ' item=['MLL', 'RDP']
# INFO:AoC:item=['PFN', 'LND'] key='QSM' item=['PFN', 'LND']
# INFO:AoC:item=['XLH', 'FNM'] key='KQX' item=['XLH', 'FNM']
# INFO:AoC:item=['GLL', 'NNP'] key='XVB' item=['GLL', 'NNP']
# INFO:AoC:item=['FPP', 'QTD'] key='JRN' item=['FPP', 'QTD']
# INFO:AoC:item=['PKM', 'XMG'] key='NMR' item=['PKM', 'XMG']
# INFO:AoC:item=['CJJ', 'JPQ'] key='PPM' item=['CJJ', 'JPQ']
# INFO:AoC:item=['CJC', 'XMX'] key='QLF' item=['CJC', 'XMX']
# INFO:AoC:item=['KBG', 'BRP'] key='CGJ' item=['KBG', 'BRP']
# INFO:AoC:item=['MTM', 'VMQ'] key='QPT' item=['MTM', 'VMQ']
# INFO:AoC:item=['BRP', 'KBG'] key='FMV' item=['BRP', 'KBG']
# INFO:AoC:item=['BGF', 'TDF'] key='GHP' item=['BGF', 'TDF']
# INFO:AoC:item=['KKV', 'JHV'] key='TPL' item=['KKV', 'JHV']
# INFO:AoC:item=['FKN', 'XPL'] key='KLR' item=['FKN', 'XPL']
# INFO:AoC:item=['QDK', 'XHH'] key='KSP' item=['QDK', 'XHH']
# INFO:AoC:item=['TDC', 'JLG'] key='JVB' item=['TDC', 'JLG']
# INFO:AoC:item=['XJR', 'KMK'] key='BMV' item=['XJR', 'KMK']
# INFO:AoC:item=['GTQ', 'QCS'] key='VRH' item=['GTQ', 'QCS']
# INFO:AoC:item=['KQK', 'VRH'] key='KLT' item=['KQK', 'VRH']
# INFO:AoC:item=['HXG', 'XRS'] key='PLM' item=['HXG', 'XRS']
# INFO:AoC:item=['LPL', 'HGH'] key='DVX' item=['LPL', 'HGH']
# INFO:AoC:item=['FMV', 'CGJ'] key='LPG' item=['FMV', 'CGJ']
# INFO:AoC:item=['MBQ', 'PCV'] key='XHH' item=['MBQ', 'PCV']
# INFO:AoC:item=['MHD', 'FFF'] key='LHJ' item=['MHD', 'FFF']
# INFO:AoC:item=['DVT', 'NTJ'] key='FGH' item=['DVT', 'NTJ']
# INFO:AoC:item=['PXV', 'FXK'] key='BRJ' item=['PXV', 'FXK']
# INFO:AoC:item=['VBV', 'FDG'] key='DTL' item=['VBV', 'FDG']
# INFO:AoC:item=['KGL', 'MFB'] key='JDV' item=['KGL', 'MFB']
# INFO:AoC:item=['PNM', 'QLF'] key='TDC' item=['PNM', 'QLF']
# INFO:AoC:item=['FHP', 'PGV'] key='PSG' item=['FHP', 'PGV']
# INFO:AoC:item=['DBR', 'BBJ'] key='VMQ' item=['DBR', 'BBJ']
# INFO:AoC:item=['SKN', 'NNQ'] key='CCK' item=['SKN', 'NNQ']
# INFO:AoC:item=['KKV', 'JHV'] key='GGM' item=['KKV', 'JHV']
# INFO:AoC:item=['GTP', 'TMK'] key='VXG' item=['GTP', 'TMK']
# INFO:AoC:item=['QRX', 'XNV'] key='CFK' item=['QRX', 'XNV']
# INFO:AoC:item=['LVJ', 'QTB'] key='BBS' item=['LVJ', 'QTB']
# INFO:AoC:item=['CDQ', 'LHF'] key='XND' item=['CDQ', 'LHF']
# INFO:AoC:item=['DTX', 'STT'] key='PKR' item=['DTX', 'STT']
# INFO:AoC:item=['RKX', 'VBF'] key='LXP' item=['RKX', 'VBF']
# INFO:AoC:item=['SSL', 'DRH'] key='JBN' item=['SSL', 'DRH']
# INFO:AoC:item=['BGL', 'NCB'] key='HTD' item=['BGL', 'NCB']
# INFO:AoC:item=['JMB', 'NXS'] key='BXG' item=['JMB', 'NXS']
# INFO:AoC:item=['XGF', 'GHQ'] key='NQG' item=['XGF', 'GHQ']
# INFO:AoC:item=['BMK', 'LST'] key='DHL' item=['BMK', 'LST']
# INFO:AoC:item=['LKD', 'LVX'] key='JGT' item=['LKD', 'LVX']
# INFO:AoC:item=['HBV', 'FQM'] key='VLJ' item=['HBV', 'FQM']
# INFO:AoC:item=['RHR', 'PBG'] key='THB' item=['RHR', 'PBG']
# INFO:AoC:item=['XQN', 'VSC'] key='NLQ' item=['XQN', 'VSC']
# INFO:AoC:item=['VMJ', 'CRS'] key='MTQ' item=['VMJ', 'CRS']
# INFO:AoC:item=['MRK', 'CFD'] key='SCT' item=['MRK', 'CFD']
# INFO:AoC:item=['HBV', 'FQM'] key='MFX' item=['HBV', 'FQM']
# INFO:AoC:item=['BBD', 'TCR'] key='BGM' item=['BBD', 'TCR']
# INFO:AoC:item=['SJB', 'CFM'] key='CJJ' item=['SJB', 'CFM']
# INFO:AoC:item=['XCT', 'JFV'] key='FTM' item=['XCT', 'JFV']
# INFO:AoC:item=['MFT', 'NLQ'] key='VVV' item=['MFT', 'NLQ']
# INFO:AoC:item=['FQN', 'PJR'] key='DSF' item=['FQN', 'PJR']
# INFO:AoC:item=['TXL', 'LCP'] key='DTS' item=['TXL', 'LCP']
# INFO:AoC:item=['RLF', 'MBT'] key='JHM' item=['RLF', 'MBT']
# INFO:AoC:item=['VTV', 'HXR'] key='NJD' item=['VTV', 'HXR']
# INFO:AoC:item=['RPS', 'KBB'] key='KPC' item=['RPS', 'KBB']
# INFO:AoC:item=['NHL', 'JGQ'] key='QVQ' item=['NHL', 'JGQ']
# INFO:AoC:item=['JPQ', 'CJJ'] key='PSD' item=['JPQ', 'CJJ']
# INFO:AoC:item=['MFK', 'LQQ'] key='LJF' item=['MFK', 'LQQ']
# INFO:AoC:item=['CGT', 'DHB'] key='LMS' item=['CGT', 'DHB']
# INFO:AoC:item=['MLL', 'RDP'] key='QTB' item=['MLL', 'RDP']
# INFO:AoC:item=['QXK', 'GFC'] key='NSS' item=['QXK', 'GFC']
# INFO:AoC:item=['FQN', 'PJR'] key='CDL' item=['FQN', 'PJR']
# INFO:AoC:item=['TGD', 'FFS'] key='BMK' item=['TGD', 'FFS']
# INFO:AoC:item=['JXG', 'QPT'] key='RCR' item=['JXG', 'QPT']
# INFO:AoC:item=['QRJ', 'SGV'] key='XDQ' item=['QRJ', 'SGV']
# INFO:AoC:item=['SGK', 'NLK'] key='RXF' item=['SGK', 'NLK']
# INFO:AoC:item=['LSH', 'JNX'] key='PKM' item=['LSH', 'JNX']
# INFO:AoC:item=['XTB', 'HQP'] key='MFB' item=['XTB', 'HQP']
# INFO:AoC:item=['LCR', 'GXR'] key='VKB' item=['LCR', 'GXR']
# INFO:AoC:item=['THC', 'JDV'] key='HNQ' item=['THC', 'JDV']
# INFO:AoC:item=['PDF', 'KVM'] key='TCJ' item=['PDF', 'KVM']
# INFO:AoC:item=['PTN', 'GJB'] key='BPP' item=['PTN', 'GJB']
# INFO:AoC:item=['KVM', 'PDF'] key='XNN' item=['KVM', 'PDF']
# INFO:AoC:item=['TJB', 'CPN'] key='TVT' item=['TJB', 'CPN']
# INFO:AoC:item=['LPP', 'GRT'] key='CRS' item=['LPP', 'GRT']
# INFO:AoC:item=['VVX', 'LXP'] key='BGS' item=['VVX', 'LXP']
# INFO:AoC:item=['NQG', 'CDF'] key='TGG' item=['NQG', 'CDF']
# INFO:AoC:item=['LMS', 'NBB'] key='SPN' item=['LMS', 'NBB']
# INFO:AoC:item=['QKT', 'TNS'] key='FKN' item=['QKT', 'TNS']
# INFO:AoC:item=['LHM', 'JFN'] key='XVF' item=['LHM', 'JFN']
# INFO:AoC:item=['XJP', 'XPM'] key='PDF' item=['XJP', 'XPM']
# INFO:AoC:item=['GHG', 'JRG'] key='CQR' item=['GHG', 'JRG']
# INFO:AoC:item=['BHX', 'KHM'] key='NDF' item=['BHX', 'KHM']
# INFO:AoC:item=['MRK', 'CFD'] key='KQP' item=['MRK', 'CFD']
# INFO:AoC:item=['KHM', 'BHX'] key='MGP' item=['KHM', 'BHX']
# INFO:AoC:item=['NGK', 'GQC'] key='TBR' item=['NGK', 'GQC']
# INFO:AoC:item=['JPV', 'MMH'] key='PCL' item=['JPV', 'MMH']
# INFO:AoC:item=['QFF', 'DPJ'] key='HXG' item=['QFF', 'DPJ']
# INFO:AoC:item=['TTG', 'QVQ'] key='FRN' item=['TTG', 'QVQ']
# INFO:AoC:item=['MHD', 'FFF'] key='NLG' item=['MHD', 'FFF']
# INFO:AoC:item=['LJP', 'JBN'] key='GLD' item=['LJP', 'JBN']
# INFO:AoC:item=['CFJ', 'PST'] key='RCD' item=['CFJ', 'PST']
# INFO:AoC:item=['TKL', 'TQX'] key='BQV' item=['TKL', 'TQX']
# INFO:AoC:item=['NFB', 'XCN'] key='SJX' item=['NFB', 'XCN']
# INFO:AoC:item=['FMV', 'CGJ'] key='DGQ' item=['FMV', 'CGJ']
# INFO:AoC:item=['NFM', 'VVM'] key='XPM' item=['NFM', 'VVM']
# INFO:AoC:item=['KKG', 'TFR'] key='BBN' item=['KKG', 'TFR']
# INFO:AoC:item=['CBM', 'FBS'] key='MRX' item=['CBM', 'FBS']
# INFO:AoC:item=['GTL', 'NCT'] key='VBJ' item=['GTL', 'NCT']
# INFO:AoC:item=['DTX', 'STT'] key='QMJ' item=['DTX', 'STT']
# INFO:AoC:item=['BMR', 'CNH'] key='BFD' item=['BMR', 'CNH']
# INFO:AoC:item=['PKR', 'QMJ'] key='VVM' item=['PKR', 'QMJ']
# INFO:AoC:item=['XSK', 'JVS'] key='VNP' item=['XSK', 'JVS']
# INFO:AoC:item=['BRX', 'BBQ'] key='HKP' item=['BRX', 'BBQ']
# INFO:AoC:item=['SNQ', 'MDX'] key='TMK' item=['SNQ', 'MDX']
# INFO:AoC:item=['PFN', 'LND'] key='GNV' item=['PFN', 'LND']
# INFO:AoC:item=['SXL', 'NJD'] key='NQC' item=['SXL', 'NJD']
# INFO:AoC:item=['DGR', 'BLX'] key='NGD' item=['DGR', 'BLX']
# INFO:AoC:item=['XDK', 'HXS'] key='MPN' item=['XDK', 'HXS']
# INFO:AoC:item=['TCV', 'SPP'] key='MCT' item=['TCV', 'SPP']
# INFO:AoC:item=['QKT', 'TNS'] key='XPL' item=['QKT', 'TNS']
# INFO:AoC:item=['XHT', 'DCC'] key='HQV' item=['XHT', 'DCC']
# INFO:AoC:item=['CVR', 'SJM'] key='NSJ' item=['CVR', 'SJM']
# INFO:AoC:item=['LLS', 'BMV'] key='XHV' item=['LLS', 'BMV']
# INFO:AoC:item=['RNN', 'LJQ'] key='HMF' item=['RNN', 'LJQ']
# INFO:AoC:item=['HMF', 'KBM'] key='TDF' item=['HMF', 'KBM']
# INFO:AoC:item=['DGN', 'QSG'] key='MHV' item=['DGN', 'QSG']
# INFO:AoC:item=['MTM', 'VMQ'] key='JXG' item=['MTM', 'VMQ']
# INFO:AoC:item=['CRK', 'QPD'] key='DTX' item=['CRK', 'QPD']
# INFO:AoC:item=['NQD', 'TNQ'] key='RQD' item=['NQD', 'TNQ']
# INFO:AoC:item=['GTL', 'NCT'] key='RFJ' item=['GTL', 'NCT']
# INFO:AoC:item=['FHT', 'NVG'] key='CGH' item=['FHT', 'NVG']
# INFO:AoC:item=['QHH', 'RXL'] key='RJD' item=['QHH', 'RXL']
# INFO:AoC:item=['VMX', 'RCD'] key='PCV' item=['VMX', 'RCD']
# INFO:AoC:item=['VMJ', 'CRS'] key='LPH' item=['VMJ', 'CRS']
# INFO:AoC:item=['VNN', 'MPD'] key='QTN' item=['VNN', 'MPD']
# INFO:AoC:item=['VRT', 'SPT'] key='DFQ' item=['VRT', 'SPT']
# INFO:AoC:item=['TMX', 'RFK'] key='LPP' item=['TMX', 'RFK']
# INFO:AoC:item=['VPD', 'JCQ'] key='VHJ' item=['VPD', 'JCQ']
# INFO:AoC:item=['BRF', 'TSF'] key='XSF' item=['BRF', 'TSF']
# INFO:AoC:item=['PRL', 'TPH'] key='GMB' item=['PRL', 'TPH']
# INFO:AoC:item=['BMR', 'CNH'] key='VGR' item=['BMR', 'CNH']
# INFO:AoC:item=['GHP', 'PVG'] key='JGQ' item=['GHP', 'PVG']
# INFO:AoC:item=['JHM', 'GFQ'] key='CFJ' item=['JHM', 'GFQ']
# INFO:AoC:item=['QTN', 'MPB'] key='FQX' item=['QTN', 'MPB']
# INFO:AoC:item=['NMH', 'HKB'] key='LJV' item=['NMH', 'HKB']
# INFO:AoC:item=['KVB', 'GVJ'] key='SVJ' item=['KVB', 'GVJ']
# INFO:AoC:item=['XMP', 'NGP'] key='QCC' item=['XMP', 'NGP']
# INFO:AoC:item=['PNM', 'QLF'] key='JLG' item=['PNM', 'QLF']
# INFO:AoC:item=['BSG', 'RQX'] key='MHD' item=['BSG', 'RQX']
# INFO:AoC:item=['LTQ', 'HKH'] key='RNN' item=['LTQ', 'HKH']
# INFO:AoC:item=['DQF', 'FTF'] key='MPD' item=['DQF', 'FTF']
# INFO:AoC:item=['RFJ', 'VBJ'] key='RKH' item=['RFJ', 'VBJ']
# INFO:AoC:item=['QCC', 'DGP'] key='QBQ' item=['QCC', 'DGP']
# INFO:AoC:item=['LSB', 'GNX'] key='RKR' item=['LSB', 'GNX']
# INFO:AoC:item=['RSD', 'HKP'] key='HRP' item=['RSD', 'HKP']
# INFO:AoC:item=['TNL', 'TJD'] key='NXX' item=['TNL', 'TJD']
# INFO:AoC:item=['CMC', 'LLJ'] key='CHG' item=['CMC', 'LLJ']
# INFO:AoC:item=['SCH', 'GMQ'] key='JVS' item=['SCH', 'GMQ']
# INFO:AoC:item=['CRK', 'QPD'] key='STT' item=['CRK', 'QPD']
# INFO:AoC:item=['CGG', 'TLR'] key='LRX' item=['CGG', 'TLR']
# INFO:AoC:item=['TRQ', 'TRQ'] key='SSL' item=['TRQ', 'TRQ']
# INFO:AoC:item=['NND', 'KLF'] key='SSM' item=['NND', 'KLF']
# INFO:AoC:item=['FQL', 'BPT'] key='XPK' item=['FQL', 'BPT']
# INFO:AoC:item=['DPC', 'QLD'] key='QXX' item=['DPC', 'QLD']
# INFO:AoC:item=['NBK', 'PCL'] key='QCS' item=['NBK', 'PCL']
# INFO:AoC:item=['VGR', 'BFD'] key='TSF' item=['VGR', 'BFD']
# INFO:AoC:item=['HPP', 'TML'] key='LBL' item=['HPP', 'TML']
# INFO:AoC:item=['BRJ', 'RJK'] key='XQN' item=['BRJ', 'RJK']
# INFO:AoC:item=['KXN', 'SKX'] key='NGX' item=['KXN', 'SKX']
# INFO:AoC:item=['JFK', 'XVP'] key='DKS' item=['JFK', 'XVP']
# INFO:AoC:item=['KHF', 'GXM'] key='TGD' item=['KHF', 'GXM']
# INFO:AoC:item=['PBG', 'RHR'] key='JRX' item=['PBG', 'RHR']
# INFO:AoC:item=['XQM', 'FCB'] key='CPC' item=['XQM', 'FCB']
# INFO:AoC:item=['QLD', 'DPC'] key='JSG' item=['QLD', 'DPC']
# INFO:AoC:item=['FPJ', 'CVG'] key='QTD' item=['FPJ', 'CVG']
# INFO:AoC:item=['HTD', 'MDN'] key='DBR' item=['HTD', 'MDN']
# INFO:AoC:item=['XSG', 'GCM'] key='DQF' item=['XSG', 'GCM']
# INFO:AoC:item=['SNF', 'SVJ'] key='DTB' item=['SNF', 'SVJ']
# INFO:AoC:item=['PJQ', 'KQX'] key='QFB' item=['PJQ', 'KQX']
# INFO:AoC:item=['RSC', 'BFH'] key='FCP' item=['RSC', 'BFH']
# INFO:AoC:item=['QMT', 'DTB'] key='BSG' item=['QMT', 'DTB']
# INFO:AoC:item=['TMK', 'GTP'] key='JJF' item=['TMK', 'GTP']
# INFO:AoC:item=['SFQ', 'VLX'] key='CCG' item=['SFQ', 'VLX']
# INFO:AoC:item=['GMS', 'HGC'] key='XSG' item=['GMS', 'HGC']
# INFO:AoC:item=['BJV', 'SLG'] key='VTN' item=['BJV', 'SLG']
# INFO:AoC:item=['MQT', 'FMJ'] key='TRH' item=['MQT', 'FMJ']
# INFO:AoC:item=['XDL', 'XKB'] key='TPH' item=['XDL', 'XKB']
# INFO:AoC:item=['BDM', 'SBT'] key='GXC' item=['BDM', 'SBT']
# INFO:AoC:item=['MHC', 'XMB'] key='DGN' item=['MHC', 'XMB']
# INFO:AoC:item=['XPS', 'TVT'] key='XCN' item=['XPS', 'TVT']
# INFO:AoC:item=['MFT', 'NLQ'] key='XLM' item=['MFT', 'NLQ']
# INFO:AoC:item=['VRT', 'SPT'] key='LVC' item=['VRT', 'SPT']
# INFO:AoC:item=['HKB', 'NMH'] key='TDX' item=['HKB', 'NMH']
# INFO:AoC:item=['LJT', 'DKB'] key='XNX' item=['LJT', 'DKB']
# INFO:AoC:item=['BSC', 'PRT'] key='DGR' item=['BSC', 'PRT']
# INFO:AoC:item=['NQC', 'QNV'] key='TJF' item=['NQC', 'QNV']
# INFO:AoC:item=['NJD', 'SXL'] key='QNV' item=['NJD', 'SXL']
# INFO:AoC:item=['DHL', 'PDV'] key='RDP' item=['DHL', 'PDV']
# INFO:AoC:item=['LKT', 'SCK'] key='CLX' item=['LKT', 'SCK']
# INFO:AoC:item=['LBL', 'XXD'] key='LKT' item=['LBL', 'XXD']
# INFO:AoC:item=['JXP', 'FFX'] key='FMS' item=['JXP', 'FFX']
# INFO:AoC:item=['CBM', 'FBS'] key='FHB' item=['CBM', 'FBS']
# INFO:AoC:item=['GHG', 'JRG'] key='CRB' item=['GHG', 'JRG']
# INFO:AoC:item=['LPG', 'DGQ'] key='GHX' item=['LPG', 'DGQ']
# INFO:AoC:item=['PLD', 'CXJ'] key='FPJ' item=['PLD', 'CXJ']
# INFO:AoC:item=['KQP', 'SCT'] key='RLJ' item=['KQP', 'SCT']
# INFO:AoC:item=['KPS', 'NQM'] key='LTQ' item=['KPS', 'NQM']
# INFO:AoC:item=['MHV', 'GDT'] key='VFJ' item=['MHV', 'GDT']
# INFO:AoC:item=['CFK', 'TCL'] key='KLF' item=['CFK', 'TCL']
# INFO:AoC:item=['VTN', 'VTN'] key='LTJ' item=['VTN', 'VTN']
# INFO:AoC:item=['GDF', 'SCN'] key='JRP' item=['GDF', 'SCN']
# INFO:AoC:item=['RRN', 'NMC'] key='SCX' item=['RRN', 'NMC']
# INFO:AoC:item=['JJF', 'VXG'] key='CMS' item=['JJF', 'VXG']
# INFO:AoC:item=['HFM', 'QKR'] key='KJZ' item=['HFM', 'QKR']
# INFO:AoC:item=['FTF', 'DQF'] key='VNN' item=['FTF', 'DQF']
# INFO:AoC:item=['RNP', 'SFL'] key='MXN' item=['RNP', 'SFL']
# INFO:AoC:item=['DGR', 'BLX'] key='LDC' item=['DGR', 'BLX']
# INFO:AoC:item=['DRG', 'MXN'] key='BBQ' item=['DRG', 'MXN']
# INFO:AoC:item=['KNH', 'NFN'] key='KBJ' item=['KNH', 'NFN']
# INFO:AoC:item=['FDG', 'VBV'] key='KQG' item=['FDG', 'VBV']
# INFO:AoC:item=['BTH', 'TLV'] key='CBT' item=['BTH', 'TLV']
# INFO:AoC:item=['LQQ', 'MFK'] key='RCF' item=['LQQ', 'MFK']
# INFO:AoC:item=['LGT', 'JGT'] key='CNH' item=['LGT', 'JGT']
# INFO:AoC:item=['DPJ', 'QFF'] key='XRS' item=['DPJ', 'QFF']
# INFO:AoC:item=['CCG', 'GBD'] key='LPJ' item=['CCG', 'GBD']
# INFO:AoC:item=['FHF', 'BJP'] key='SCN' item=['FHF', 'BJP']
# INFO:AoC:item=['BHM', 'SSM'] key='NVG' item=['BHM', 'SSM']
# INFO:AoC:item=['CLX', 'BRQ'] key='DVL' item=['CLX', 'BRQ']
# INFO:AoC:item=['DKS', 'HQT'] key='CPN' item=['DKS', 'HQT']
# INFO:AoC:item=['FRM', 'VQC'] key='SPC' item=['FRM', 'VQC']
# INFO:AoC:item=['JXP', 'FFX'] key='KQH' item=['JXP', 'FFX']
# INFO:AoC:item=['HQV', 'BLR'] key='VRT' item=['HQV', 'BLR']
# INFO:AoC:item=['LJF', 'RCF'] key='HDX' item=['LJF', 'RCF']
# INFO:AoC:item=['CVD', 'HNC'] key='XXR' item=['CVD', 'HNC']
# INFO:AoC:item=['NXS', 'JMB'] key='GVQ' item=['NXS', 'JMB']
# INFO:AoC:item=['CHG', 'CKK'] key='SNQ' item=['CHG', 'CKK']
# INFO:AoC:item=['PQL', 'MBC'] key='FPH' item=['PQL', 'MBC']
# INFO:AoC:item=['SSB', 'DTF'] key='PBK' item=['SSB', 'DTF']
# INFO:AoC:item=['JQF', 'JQF'] key='LPL' item=['JQF', 'JQF']
# INFO:AoC:item=['KXN', 'SKX'] key='VQL' item=['KXN', 'SKX']
# INFO:AoC:item=['LHF', 'CDQ'] key='VMB' item=['LHF', 'CDQ']
# INFO:AoC:item=['RQD', 'DFT'] key='FNM' item=['RQD', 'DFT']
# INFO:AoC:item=['BSC', 'PRT'] key='BLX' item=['BSC', 'PRT']
# INFO:AoC:item=['BGF', 'TDF'] key='PVG' item=['BGF', 'TDF']
# INFO:AoC:item=['DGP', 'QCC'] key='HPH' item=['DGP', 'QCC']
# INFO:AoC:item=['FJC', 'VGV'] key='PKT' item=['FJC', 'VGV']
# INFO:AoC:item=['VBP', 'KDQ'] key='KNV' item=['VBP', 'KDQ']
# INFO:AoC:item=['NBP', 'XHM'] key='PJS' item=['NBP', 'XHM']
# INFO:AoC:item=['JLP', 'NQP'] key='XNZ' item=['JLP', 'NQP']
# INFO:AoC:item=['SRJ', 'QNM'] key='BJV' item=['SRJ', 'QNM']
# INFO:AoC:item=['PBK', 'LXX'] key='CBM' item=['PBK', 'LXX']
# INFO:AoC:item=['SFS', 'JSV'] key='QSX' item=['SFS', 'JSV']
# INFO:AoC:item=['RSC', 'BFH'] key='VFR' item=['RSC', 'BFH']
# INFO:AoC:item=['MHC', 'XMB'] key='QSG' item=['MHC', 'XMB']
# INFO:AoC:item=['QCS', 'GTQ'] key='KQK' item=['QCS', 'GTQ']
# INFO:AoC:item=['RTX', 'XPK'] key='XXM' item=['RTX', 'XPK']
# INFO:AoC:item=['FPP', 'QTD'] key='JPB' item=['FPP', 'QTD']
# INFO:AoC:item=['TRQ', 'BRB'] key='DRH' item=['TRQ', 'BRB']
# INFO:AoC:item=['RKH', 'RKH'] key='MSJ' item=['RKH', 'RKH']
# INFO:AoC:item=['RJX', 'NVQ'] key='MRK' item=['RJX', 'NVQ']
# INFO:AoC:item=['BRX', 'BBQ'] key='RSD' item=['BRX', 'BBQ']
# INFO:AoC:item=['PBK', 'LXX'] key='FBS' item=['PBK', 'LXX']
# INFO:AoC:item=['MSJ', 'MSJ'] key='FMB' item=['MSJ', 'MSJ']
# INFO:AoC:item=['RQQ', 'TBR'] key='BJP' item=['RQQ', 'TBR']
# INFO:AoC:item=['GJX', 'TRH'] key='GTL' item=['GJX', 'TRH']
# INFO:AoC:item=['HDC', 'MDJ'] key='GMQ' item=['HDC', 'MDJ']
# INFO:AoC:item=['HGC', 'GMS'] key='GCM' item=['HGC', 'GMS']
# INFO:AoC:item=['FTM', 'XGT'] key='PJJ' item=['FTM', 'XGT']
# INFO:AoC:item=['XHV', 'KDJ'] key='AAA' item=['XHV', 'KDJ']
# INFO:AoC:item=['MVX', 'DDX'] key='VBP' item=['MVX', 'DDX']
# INFO:AoC:item=['VSX', 'MCT'] key='SQB' item=['VSX', 'MCT']
# INFO:AoC:item=['RGG', 'SHQ'] key='XFQ' item=['RGG', 'SHQ']
# INFO:AoC:item=['JVH', 'LMR'] key='RQG' item=['JVH', 'LMR']
# INFO:AoC:item=['FHB', 'MRX'] key='GXM' item=['FHB', 'MRX']
# INFO:AoC:item=['JRX', 'THB'] key='QKT' item=['JRX', 'THB']
# INFO:AoC:item=['QSX', 'QKN'] key='RLF' item=['QSX', 'QKN']
# INFO:AoC:item=['NQP', 'JLP'] key='PMT' item=['NQP', 'JLP']
# INFO:AoC:item=['CJC', 'XMX'] key='PNM' item=['CJC', 'XMX']
# INFO:AoC:item=['GVJ', 'KVB'] key='SNF' item=['GVJ', 'KVB']
# INFO:AoC:item=['VVM', 'NFM'] key='XJP' item=['VVM', 'NFM']
# INFO:AoC:item=['FQH', 'FPH'] key='NFN' item=['FQH', 'FPH']
# INFO:AoC:item=['QPT', 'JXG'] key='BJG' item=['QPT', 'JXG']
# INFO:AoC:item=['JHM', 'GFQ'] key='PST' item=['JHM', 'GFQ']
# INFO:AoC:item=['HNC', 'CVD'] key='RXB' item=['HNC', 'CVD']
# INFO:AoC:item=['KKB', 'PQZ'] key='XNH' item=['KKB', 'PQZ']
# INFO:AoC:item=['SFL', 'RNP'] key='DRG' item=['SFL', 'RNP']
# INFO:AoC:item=['DSM', 'JVQ'] key='MRB' item=['DSM', 'JVQ']
# INFO:AoC:item=['SJX', 'TMR'] key='SJB' item=['SJX', 'TMR']
# INFO:AoC:item=['JGT', 'LGT'] key='BMR' item=['JGT', 'LGT']
# INFO:AoC:item=['LRX', 'CLT'] key='LND' item=['LRX', 'CLT']
# INFO:AoC:item=['KPV', 'RLJ'] key='MBC' item=['KPV', 'RLJ']
# INFO:AoC:item=['CGH', 'FHK'] key='XHT' item=['CGH', 'FHK']
# INFO:AoC:item=['CPN', 'TJB'] key='XPS' item=['CPN', 'TJB']
# INFO:AoC:item=['CQR', 'CRB'] key='RRR' item=['CQR', 'CRB']
# INFO:AoC:item=['JVH', 'LMR'] key='GPB' item=['JVH', 'LMR']
# INFO:AoC:item=['GNV', 'QSM'] key='PTN' item=['GNV', 'QSM']
# INFO:AoC:item=['CCK', 'NJF'] key='DHB' item=['CCK', 'NJF']
# INFO:AoC:item=['RCF', 'LJF'] key='XGV' item=['RCF', 'LJF']
# INFO:AoC:item=['KGL', 'MFB'] key='THC' item=['KGL', 'MFB']
# INFO:AoC:item=['MGP', 'NDF'] key='JSV' item=['MGP', 'NDF']
# INFO:AoC:item=['RQD', 'DFT'] key='XLH' item=['RQD', 'DFT']
# INFO:AoC:item=['HBS', 'DTS'] key='PXV' item=['HBS', 'DTS']
# INFO:AoC:item=['SKG', 'XVB'] key='FMJ' item=['SKG', 'XVB']
# INFO:AoC:item=['GLL', 'NNP'] key='SKG' item=['GLL', 'NNP']
# INFO:AoC:item=['KCM', 'FTD'] key='VBM' item=['KCM', 'FTD']
# INFO:AoC:item=['STC', 'GLD'] key='BHX' item=['STC', 'GLD']
# INFO:AoC:item=['HNQ', 'SXD'] key='RPS' item=['HNQ', 'SXD']
# INFO:AoC:item=['THB', 'JRX'] key='TNS' item=['THB', 'JRX']
# INFO:AoC:item=['KSP', 'LDJ'] key='PJR' item=['KSP', 'LDJ']
# INFO:AoC:item=['DSM', 'JVQ'] key='PGJ' item=['DSM', 'JVQ']
# INFO:AoC:item=['NND', 'KLF'] key='BHM' item=['NND', 'KLF']
# INFO:AoC:item=['VXH', 'HHB'] key='BDR' item=['VXH', 'HHB']
# INFO:AoC:item=['PNV', 'JGF'] key='JVQ' item=['PNV', 'JGF']
# INFO:AoC:item=['FMB', 'QKV'] key='NQM' item=['FMB', 'QKV']
# INFO:AoC:item=['XGV', 'HDX'] key='VDM' item=['XGV', 'HDX']
# INFO:AoC:item=['XNN', 'TCJ'] key='XNV' item=['XNN', 'TCJ']
# INFO:AoC:item=['CVV', 'JSJ'] key='SRF' item=['CVV', 'JSJ']
# INFO:AoC:item=['RQQ', 'TBR'] key='FHF' item=['RQQ', 'TBR']
# INFO:AoC:item=['PKN', 'KLG'] key='TMX' item=['PKN', 'KLG']
# INFO:AoC:item=['PKM', 'XMG'] key='HNF' item=['PKM', 'XMG']
# INFO:AoC:item=['KPS', 'NQM'] key='HKH' item=['KPS', 'NQM']
# INFO:AoC:item=['VXM', 'GXC'] key='JFN' item=['VXM', 'GXC']
# INFO:AoC:item=['XCN', 'NFB'] key='TMR' item=['XCN', 'NFB']
# INFO:AoC:item=['XGF', 'GHQ'] key='CDF' item=['XGF', 'GHQ']
# INFO:AoC:item=['QTN', 'MPB'] key='DCN' item=['QTN', 'MPB']
# INFO:AoC:item=['DNM', 'DNM'] key='HKV' item=['DNM', 'DNM']
# INFO:AoC:item=['LHM', 'JFN'] key='XRT' item=['LHM', 'JFN']
# INFO:AoC:item=['PRL', 'TPH'] key='JGX' item=['PRL', 'TPH']
# INFO:AoC:item=['RPX', 'PQH'] key='LFH' item=['RPX', 'PQH']
# INFO:AoC:item=['DJF', 'RRR'] key='RLL' item=['DJF', 'RRR']
# INFO:AoC:item=['PPH', 'RMJ'] key='NLK' item=['PPH', 'RMJ']
# INFO:AoC:item=['XHM', 'NBP'] key='JNQ' item=['XHM', 'NBP']
# INFO:AoC:item=['HCB', 'KLT'] key='RXL' item=['HCB', 'KLT']
# INFO:AoC:item=['JRJ', 'SCX'] key='FFX' item=['JRJ', 'SCX']
# INFO:AoC:item=['TLD', 'RJD'] key='JVH' item=['TLD', 'RJD']
# INFO:AoC:item=['FNR', 'TSV'] key='JRC' item=['FNR', 'TSV']
# INFO:AoC:item=['MRX', 'FHB'] key='KHF' item=['MRX', 'FHB']
# INFO:AoC:item=['BXG', 'GVQ'] key='HPT' item=['BXG', 'GVQ']
# INFO:AoC:item=['TSD', 'BGM'] key='PLD' item=['TSD', 'BGM']
# INFO:AoC:item=['XGV', 'HDX'] key='VND' item=['XGV', 'HDX']
# INFO:AoC:item=['XFF', 'BTT'] key='GKL' item=['XFF', 'BTT']
# INFO:AoC:item=['BRJ', 'RJK'] key='VSC' item=['BRJ', 'RJK']
# INFO:AoC:item=['GJB', 'PTN'] key='KTM' item=['GJB', 'PTN']
# INFO:AoC:item=['XBG', 'VHJ'] key='NMH' item=['XBG', 'VHJ']
# INFO:AoC:item=['FMB', 'FMB'] key='KPS' item=['FMB', 'FMB']
# INFO:AoC:item=['VLJ', 'MFX'] key='XTK' item=['VLJ', 'MFX']
# INFO:AoC:item=['HQS', 'MNP'] key='HDC' item=['HQS', 'MNP']
# INFO:AoC:item=['FCP', 'VFR'] key='TRK' item=['FCP', 'VFR']
# INFO:AoC:item=['GJT', 'DVL'] key='MKQ' item=['GJT', 'DVL']
# INFO:AoC:item=['FMS', 'KQH'] key='CGG' item=['FMS', 'KQH']
# INFO:AoC:item=['GMQ', 'SCH'] key='XSK' item=['GMQ', 'SCH']
# INFO:AoC:item=['TGG', 'XCD'] key='JJX' item=['TGG', 'XCD']
# INFO:AoC:item=['SFS', 'JSV'] key='QKN' item=['SFS', 'JSV']
# INFO:AoC:item=['JPB', 'JRN'] key='RPX' item=['JPB', 'JRN']
# INFO:AoC:item=['QDH', 'QDH'] key='JXH' item=['QDH', 'QDH']
# INFO:AoC:item=['KQX', 'PJQ'] key='GHT' item=['KQX', 'PJQ']
# INFO:AoC:item=['TGV', 'QNN'] key='XCT' item=['TGV', 'QNN']
# INFO:AoC:item=['NSJ', 'GRB'] key='BDM' item=['NSJ', 'GRB']
# INFO:AoC:item=['NGX', 'VQL'] key='MMH' item=['NGX', 'VQL']
# INFO:AoC:item=['PMB', 'XDQ'] key='FVB' item=['PMB', 'XDQ']
# INFO:AoC:item=['TDX', 'LJV'] key='NGK' item=['TDX', 'LJV']
# INFO:AoC:item=['VVV', 'XLM'] key='QNM' item=['VVV', 'XLM']
# INFO:AoC:item=['FMS', 'KQH'] key='TLR' item=['FMS', 'KQH']
# INFO:AoC:item=['LMS', 'NBB'] key='VPX' item=['LMS', 'NBB']
# INFO:AoC:item=['FNM', 'XLH'] key='PJQ' item=['FNM', 'XLH']
# INFO:AoC:item=['BHM', 'SSM'] key='FHT' item=['BHM', 'SSM']
# INFO:AoC:item=['LSB', 'GNX'] key='TJQ' item=['LSB', 'GNX']
# INFO:AoC:item=['XJR', 'KMK'] key='LLS' item=['XJR', 'KMK']
# INFO:AoC:item=['QNN', 'TGV'] key='JFV' item=['QNN', 'TGV']
# INFO:AoC:item=['RFJ', 'VBJ'] key='LHA' item=['RFJ', 'VBJ']
# INFO:AoC:item=['GXC', 'VXM'] key='LHM' item=['GXC', 'VXM']
# INFO:AoC:item=['NQP', 'JLP'] key='RHA' item=['NQP', 'JLP']
# INFO:AoC:item=['LVK', 'DCV'] key='JHV' item=['LVK', 'DCV']
# INFO:AoC:item=['SPC', 'SNP'] key='XGF' item=['SPC', 'SNP']
# INFO:AoC:item=['CDL', 'DSF'] key='LSH' item=['CDL', 'DSF']
# INFO:AoC:item=['LDC', 'NGD'] key='KXN' item=['LDC', 'NGD']
# INFO:AoC:item=['VFJ', 'GJM'] key='XMP' item=['VFJ', 'GJM']
# INFO:AoC:item=['TDC', 'JLG'] key='BDB' item=['TDC', 'JLG']
# INFO:AoC:item=['PKT', 'BLB'] key='DVT' item=['PKT', 'BLB']
# INFO:AoC:item=['SCT', 'KQP'] key='KPV' item=['SCT', 'KQP']
# INFO:AoC:item=['BJG', 'RCR'] key='GLL' item=['BJG', 'RCR']
# INFO:AoC:item=['DNM', 'XNH'] key='LSK' item=['DNM', 'XNH']
# INFO:AoC:item=['DNF', 'FRN'] key='KRC' item=['DNF', 'FRN']
# INFO:AoC:item=['SQG', 'GXV'] key='TQX' item=['SQG', 'GXV']
# INFO:AoC:item=['LJV', 'TDX'] key='GQC' item=['LJV', 'TDX']
# INFO:AoC:item=['KHF', 'GXM'] key='FFS' item=['KHF', 'GXM']
# INFO:AoC:item=['VVV', 'XLM'] key='SRJ' item=['VVV', 'XLM']
# INFO:AoC:item=['NTH', 'VPH'] key='TJD' item=['NTH', 'VPH']
# INFO:AoC:item=['DHS', 'JJX'] key='LHV' item=['DHS', 'JJX']
# INFO:AoC:item=['CSL', 'GHX'] key='FQM' item=['CSL', 'GHX']
# INFO:AoC:item=['DGQ', 'LPG'] key='CSL' item=['DGQ', 'LPG']
# INFO:AoC:item=['DHS', 'JJX'] key='PCM' item=['DHS', 'JJX']
# INFO:AoC:item=['FMJ', 'MQT'] key='GJX' item=['FMJ', 'MQT']
# INFO:AoC:item=['KQG', 'DTL'] key='DTV' item=['KQG', 'DTL']
# INFO:AoC:item=['PVR', 'PKK'] key='RHC' item=['PVR', 'PKK']
# INFO:AoC:item=['LPH', 'MTQ'] key='RKX' item=['LPH', 'MTQ']
# INFO:AoC:item=['FNR', 'TSV'] key='KGB' item=['FNR', 'TSV']
# INFO:AoC:item=['HPT', 'VXF'] key='XQM' item=['HPT', 'VXF']
# INFO:AoC:item=['KNH', 'NFN'] key='MGV' item=['KNH', 'NFN']
# INFO:AoC:item=['KCL', 'KCG'] key='KSG' item=['KCL', 'KCG']
# INFO:AoC:item=['STN', 'KNV'] key='TSV' item=['STN', 'KNV']
# INFO:AoC:item=['SRJ', 'QNM'] key='SLG' item=['SRJ', 'QNM']
# INFO:AoC:item=['QSX', 'QKN'] key='MBT' item=['QSX', 'QKN']
# INFO:AoC:item=['QDH', 'LXB'] key='BTG' item=['QDH', 'LXB']
# INFO:AoC:item=['RQG', 'GPB'] key='GXV' item=['RQG', 'GPB']
# INFO:AoC:item=['BPP', 'KTM'] key='BTH' item=['BPP', 'KTM']
# INFO:AoC:item=['PKH', 'SQB'] key='NVQ' item=['PKH', 'SQB']
# INFO:AoC:item=['NCB', 'BGL'] key='MDN' item=['NCB', 'BGL']
# INFO:AoC:item=['KTG', 'CQK'] key='PKN' item=['KTG', 'CQK']
# INFO:AoC:item=['HRG', 'VDX'] key='LXB' item=['HRG', 'VDX']
# INFO:AoC:item=['HXG', 'XRS'] key='NVT' item=['HXG', 'XRS']
# INFO:AoC:item=['FVB', 'SHD'] key='QNN' item=['FVB', 'SHD']
# INFO:AoC:item=['XJP', 'XPM'] key='KVM' item=['XJP', 'XPM']
# INFO:AoC:item=['HNF', 'NMR'] key='VPD' item=['HNF', 'NMR']
# INFO:AoC:item=['JKG', 'BBS'] key='MRL' item=['JKG', 'BBS']
# INFO:AoC:item=['GFS', 'NSS'] key='SGV' item=['GFS', 'NSS']
# INFO:AoC:item=['XTB', 'HQP'] key='KGL' item=['XTB', 'HQP']
# INFO:AoC:item=['JFV', 'XCT'] key='XGT' item=['JFV', 'XCT']
# INFO:AoC:item=['XBG', 'VHJ'] key='HKB' item=['XBG', 'VHJ']
# INFO:AoC:item=['JPL', 'SPB'] key='CMC' item=['JPL', 'SPB']
# INFO:AoC:item=['TRK', 'KPK'] key='TDJ' item=['TRK', 'KPK']
# INFO:AoC:item=['SLG', 'BJV'] key='XLZ' item=['SLG', 'BJV']
# INFO:AoC:item=['GGM', 'TPL'] key='CHX' item=['GGM', 'TPL']
# INFO:AoC:item=['DDX', 'MVX'] key='KDQ' item=['DDX', 'MVX']
# INFO:AoC:item=['KJR', 'HMS'] key='HFM' item=['KJR', 'HMS']
# INFO:AoC:item=['QMT', 'DTB'] key='RQX' item=['QMT', 'DTB']
# INFO:AoC:item=['HGD', 'RHM'] key='KQR' item=['HGD', 'RHM']
# INFO:AoC:item=['JCQ', 'VPD'] key='XBG' item=['JCQ', 'VPD']
# INFO:AoC:item=['NGX', 'VQL'] key='JPV' item=['NGX', 'VQL']
# INFO:AoC:item=['PST', 'CFJ'] key='VMX' item=['PST', 'CFJ']
# INFO:AoC:item=['TSF', 'BRF'] key='XXT' item=['TSF', 'BRF']
# INFO:AoC:item=['KTM', 'BPP'] key='TLV' item=['KTM', 'BPP']
# INFO:AoC:item=['FHK', 'CGH'] key='DCC' item=['FHK', 'CGH']
# INFO:AoC:item=['XRJ', 'DKL'] key='XVP' item=['XRJ', 'DKL']
# INFO:AoC:item=['VRH', 'KQK'] key='HCB' item=['VRH', 'KQK']
# INFO:AoC:item=['MPN', 'QTM'] key='LCP' item=['MPN', 'QTM']
# INFO:AoC:item=['FXX', 'PSG'] key='CSX' item=['FXX', 'PSG']
# INFO:AoC:item=['MSJ', 'HKJ'] key='QKV' item=['MSJ', 'HKJ']
# INFO:AoC:item=['FSN', 'FSN'] key='KCL' item=['FSN', 'FSN']
# INFO:AoC:item=['HHB', 'VXH'] key='JNC' item=['HHB', 'VXH']
# INFO:AoC:item=['RMJ', 'PPH'] key='SGK' item=['RMJ', 'PPH']
# INFO:AoC:item=['BVG', 'PNH'] key='CJM' item=['BVG', 'PNH']
# INFO:AoC:item=['VTN', 'XLZ'] key='MGN' item=['VTN', 'XLZ']
# INFO:AoC:item=['HJH', 'BGS'] key='HGD' item=['HJH', 'BGS']
# INFO:AoC:item=['VBP', 'KDQ'] key='STN' item=['VBP', 'KDQ']
# INFO:AoC:item=['RLL', 'HMN'] key='NPR' item=['RLL', 'HMN']
# INFO:AoC:item=['QRM', 'BBN'] key='RRN' item=['QRM', 'BBN']
# INFO:AoC:item=['PMB', 'XDQ'] key='SHD' item=['PMB', 'XDQ']
# INFO:AoC:item=['JFK', 'XVP'] key='HQT' item=['JFK', 'XVP']
# INFO:AoC:item=['DVX', 'DGL'] key='JSB' item=['DVX', 'DGL']
# INFO:AoC:item=['RSD', 'HKP'] key='TVL' item=['RSD', 'HKP']
# INFO:AoC:item=['JSJ', 'CVV'] key='PBL' item=['JSJ', 'CVV']
# INFO:AoC:item=['XNX', 'MXV'] key='KBG' item=['XNX', 'MXV']
# INFO:AoC:item=['NVT', 'PLM'] key='HGN' item=['NVT', 'PLM']
# INFO:AoC:item=['PMT', 'XNZ'] key='BRB' item=['PMT', 'XNZ']
# INFO:AoC:item=['HKV', 'LSK'] key='XMX' item=['HKV', 'LSK']
# INFO:AoC:item=['LSH', 'JNX'] key='XMG' item=['LSH', 'JNX']
# INFO:AoC:item=['LHJ', 'NLG'] key='BTT' item=['LHJ', 'NLG']
# INFO:AoC:item=['LHV', 'PCM'] key='TFR' item=['LHV', 'PCM']
# INFO:AoC:item=['XVG', 'PBF'] key='MVX' item=['XVG', 'PBF']
# INFO:AoC:item=['SMV', 'GSJ'] key='NBP' item=['SMV', 'GSJ']
# INFO:AoC:item=['KRC', 'DLL'] key='JDN' item=['KRC', 'DLL']
# INFO:AoC:item=['VRX', 'XTK'] key='QLD' item=['VRX', 'XTK']
# INFO:AoC:item=['GHB', 'RXF'] key='MSF' item=['GHB', 'RXF']
# INFO:AoC:item=['XMT', 'TDJ'] key='DPJ' item=['XMT', 'TDJ']
# INFO:AoC:item=['SRH', 'VDT'] key='SPP' item=['SRH', 'VDT']
# INFO:AoC:item=['GSM', 'CJM'] key='LQQ' item=['GSM', 'CJM']
# INFO:AoC:item=['JPV', 'MMH'] key='NBK' item=['JPV', 'MMH']
# INFO:AoC:item=['SRF', 'PBL'] key='VBV' item=['SRF', 'PBL']
# INFO:AoC:item=['SNP', 'SPC'] key='GHQ' item=['SNP', 'SPC']
# INFO:AoC:item=['DRD', 'BGR'] key='SSB' item=['DRD', 'BGR']
# INFO:AoC:item=['PGJ', 'MRB'] key='CVD' item=['PGJ', 'MRB']
# INFO:AoC:item=['CVG', 'FPJ'] key='FPP' item=['CVG', 'FPJ']
# INFO:AoC:item=['TNQ', 'NQD'] key='DFT' item=['TNQ', 'NQD']
# INFO:AoC:item=['MRL', 'QGF'] key='PQZ' item=['MRL', 'QGF']
# INFO:AoC:item=['RKR', 'TJQ'] key='SKN' item=['RKR', 'TJQ']
# INFO:AoC:item=['HGN', 'RPM'] key='GMS' item=['HGN', 'RPM']
# INFO:AoC:item=['FRN', 'DNF'] key='DLL' item=['FRN', 'DNF']
# INFO:AoC:item=['VBM', 'BPC'] key='LXT' item=['VBM', 'BPC']
# INFO:AoC:item=['QKR', 'HFM'] key='CVA' item=['QKR', 'HFM']
# INFO:AoC:item=['PGJ', 'MRB'] key='HNC' item=['PGJ', 'MRB']
# INFO:AoC:item=['XFF', 'BTT'] key='BRV' item=['XFF', 'BTT']
# INFO:AoC:item=['BPT', 'FQL'] key='RTX' item=['BPT', 'FQL']
# INFO:AoC:item=['SVS', 'DTV'] key='NQD' item=['SVS', 'DTV']
# INFO:AoC:item=['DTV', 'SVS'] key='TNQ' item=['DTV', 'SVS']
# INFO:AoC:item=['RHC', 'LLN'] key='GBR' item=['RHC', 'LLN']
# INFO:AoC:item=['DRJ', 'MHF'] key='XKB' item=['DRJ', 'MHF']
# INFO:AoC:item=['QMJ', 'PKR'] key='NFM' item=['QMJ', 'PKR']
# INFO:AoC:item=['LHJ', 'NLG'] key='XFF' item=['LHJ', 'NLG']
# INFO:AoC:item=['XNV', 'QRX'] key='TCL' item=['XNV', 'QRX']
# INFO:AoC:item=['CFL', 'QJK'] key='DRJ' item=['CFL', 'QJK']
# INFO:AoC:item=['GNV', 'QSM'] key='GJB' item=['GNV', 'QSM']
# INFO:AoC:item=['PNT', 'KDG'] key='LSB' item=['PNT', 'KDG']
# INFO:AoC:item=['CSX', 'LFM'] key='PNH' item=['CSX', 'LFM']
# INFO:AoC:item=['VSG', 'VSG'] key='HRG' item=['VSG', 'VSG']
# INFO:AoC:item=['TJF', 'XSD'] key='DNX' item=['TJF', 'XSD']
# INFO:AoC:item=['DCV', 'LVK'] key='KKV' item=['DCV', 'LVK']
# INFO:AoC:item=['HCB', 'KLT'] key='QHH' item=['HCB', 'KLT']
# INFO:AoC:item=['XSG', 'GCM'] key='FTF' item=['XSG', 'GCM']
# INFO:AoC:item=['XQM', 'FCB'] key='NDH' item=['XQM', 'FCB']
# INFO:AoC:item=['SBT', 'BDM'] key='VXM' item=['SBT', 'BDM']
# INFO:AoC:item=['LXT', 'HHC'] key='PNV' item=['LXT', 'HHC']
# INFO:AoC:item=['FPH', 'FQH'] key='KNH' item=['FPH', 'FQH']
# INFO:AoC:item=['CMC', 'LLJ'] key='CKK' item=['CMC', 'LLJ']
# INFO:AoC:item=['NPR', 'BGX'] key='BBD' item=['NPR', 'BGX']
# INFO:AoC:item=['LCR', 'GXR'] key='CKC' item=['LCR', 'GXR']
# INFO:AoC:item=['BMK', 'LST'] key='PDV' item=['BMK', 'LST']
# INFO:AoC:item=['RLJ', 'KPV'] key='PQL' item=['RLJ', 'KPV']
# INFO:AoC:item=['CHG', 'CKK'] key='MDX' item=['CHG', 'CKK']
# INFO:AoC:item=['QPS', 'QPS'] key='BSC' item=['QPS', 'QPS']
# INFO:AoC:item=['NTJ', 'DVT'] key='VLK' item=['NTJ', 'DVT']
# INFO:AoC:item=['MRV', 'KQR'] key='KDG' item=['MRV', 'KQR']
# INFO:AoC:item=['MRV', 'KQR'] key='PNT' item=['MRV', 'KQR']
# INFO:AoC:item=['VPH', 'NTH'] key='TNL' item=['VPH', 'NTH']
# INFO:AoC:item=['PVR', 'PKK'] key='LLN' item=['PVR', 'PKK']
# INFO:AoC:item=['XXT', 'XSF'] key='MHC' item=['XXT', 'XSF']
# INFO:AoC:item=['KCL', 'KCL'] key='QPS' item=['KCL', 'KCL']
# INFO:AoC:item=['TJQ', 'RKR'] key='NNQ' item=['TJQ', 'RKR']
# INFO:AoC:item=['PVG', 'GHP'] key='NHL' item=['PVG', 'GHP']
# INFO:AoC:item=['GRT', 'LPP'] key='VMJ' item=['GRT', 'LPP']
# INFO:AoC:item=['NDF', 'MGP'] key='SFS' item=['NDF', 'MGP']
# INFO:AoC:item=['QXX', 'JSG'] key='BGR' item=['QXX', 'JSG']
# INFO:AoC:item=['FQJ', 'CHX'] key='QXK' item=['FQJ', 'CHX']
# INFO:AoC:item=['JGF', 'PNV'] key='DSM' item=['JGF', 'PNV']
# INFO:AoC:item=['LLN', 'RHC'] key='MBR' item=['LLN', 'RHC']
# INFO:AoC:item=['VGR', 'BFD'] key='BRF' item=['VGR', 'BFD']
# INFO:AoC:item=['RCR', 'BJG'] key='NNP' item=['RCR', 'BJG']
# INFO:AoC:item=['QGF', 'MRL'] key='KKB' item=['QGF', 'MRL']
# INFO:AoC:item=['QJK', 'CFL'] key='MHF' item=['QJK', 'CFL']
# INFO:AoC:item=['SKG', 'XVB'] key='MQT' item=['SKG', 'XVB']
# INFO:AoC:item=['VXG', 'JJF'] key='HTJ' item=['VXG', 'JJF']
# INFO:AoC:item=['XVF', 'XRT'] key='JRG' item=['XVF', 'XRT']
# INFO:AoC:item=['FFS', 'TGD'] key='LST' item=['FFS', 'TGD']
# INFO:AoC:item=['FCP', 'VFR'] key='KPK' item=['FCP', 'VFR']
# INFO:AoC:item=['DHL', 'PDV'] key='MLL' item=['DHL', 'PDV']
# INFO:AoC:item=['BBN', 'QRM'] key='NMC' item=['BBN', 'QRM']
# INFO:AoC:item=['BJV', 'SLG'] key='LDA' item=['BJV', 'SLG']
# INFO:AoC:item=['JRC', 'KGB'] key='RHR' item=['JRC', 'KGB']
# INFO:AoC:item=['VND', 'VDM'] key='PVR' item=['VND', 'VDM']
# INFO:AoC:item=['VPX', 'SPN'] key='NXS' item=['VPX', 'SPN']
# INFO:AoC:item=['CQG', 'GRP'] key='RSC' item=['CQG', 'GRP']
# INFO:AoC:item=['MKQ', 'GRF'] key='PGC' item=['MKQ', 'GRF']
# INFO:AoC:item=['GGM', 'TPL'] key='FQJ' item=['GGM', 'TPL']
# INFO:AoC:item=['RPX', 'PQH'] key='HHR' item=['RPX', 'PQH']
# INFO:AoC:item=['PLM', 'NVT'] key='RPM' item=['PLM', 'NVT']
# INFO:AoC:item=['LJP', 'JBN'] key='STC' item=['LJP', 'JBN']
# INFO:AoC:item=['SVJ', 'SNF'] key='QMT' item=['SVJ', 'SNF']
# INFO:AoC:item=['RPS', 'KBB'] key='NXB' item=['RPS', 'KBB']
# INFO:AoC:item=['BRQ', 'CLX'] key='GJT' item=['BRQ', 'CLX']
# INFO:AoC:item=['VMB', 'XND'] key='DKB' item=['VMB', 'XND']
# INFO:AoC:item=['TNL', 'TJD'] key='BNL' item=['TNL', 'TJD']
# INFO:AoC:item=['DTL', 'KQG'] key='SVS' item=['DTL', 'KQG']
# INFO:AoC:item=['FQJ', 'CHX'] key='GFC' item=['FQJ', 'CHX']
# INFO:AoC:item=['FRM', 'VQC'] key='SNP' item=['FRM', 'VQC']
# INFO:AoC:item=['GHT', 'QFB'] key='KCM' item=['GHT', 'QFB']
# INFO:AoC:item=['JRP', 'NRD'] key='JSJ' item=['JRP', 'NRD']
# INFO:AoC:item=['HLK', 'XFM'] key='MNP' item=['HLK', 'XFM']
# INFO:AoC:item=['HMF', 'KBM'] key='BGF' item=['HMF', 'KBM']
# INFO:AoC:item=['XFM', 'HLK'] key='HQS' item=['XFM', 'HLK']
# INFO:AoC:item=['DVL', 'GJT'] key='GRF' item=['DVL', 'GJT']
# INFO:AoC:item=['HGN', 'RPM'] key='HGC' item=['HGN', 'RPM']
# INFO:AoC:item=['MBR', 'GBR'] key='SFQ' item=['MBR', 'GBR']
# INFO:AoC:item=['NJF', 'CCK'] key='CGT' item=['NJF', 'CCK']
# INFO:AoC:item=['XVF', 'XRT'] key='GHG' item=['XVF', 'XRT']
# INFO:AoC:item=['PKT', 'BLB'] key='NTJ' item=['PKT', 'BLB']
# INFO:AoC:item=['NNQ', 'SKN'] key='NJF' item=['NNQ', 'SKN']
# INFO:AoC:item=['BLR', 'HQV'] key='SPT' item=['BLR', 'HQV']
# INFO:AoC:item=['CPC', 'NDH'] key='XJR' item=['CPC', 'NDH']
# INFO:AoC:item=['GQC', 'NGK'] key='RQQ' item=['GQC', 'NGK']
# INFO:AoC:item=['DRJ', 'MHF'] key='XDL' item=['DRJ', 'MHF']
# INFO:AoC:item=['QTB', 'LVJ'] key='JKG' item=['QTB', 'LVJ']
# INFO:AoC:item=['SGK', 'NLK'] key='GHB' item=['SGK', 'NLK']
# INFO:AoC:item=['STC', 'GLD'] key='KHM' item=['STC', 'GLD']
# INFO:AoC:item=['GHB', 'RXF'] key='BKM' item=['GHB', 'RXF']
# INFO:AoC:item=['DCC', 'XHT'] key='BLR' item=['DCC', 'XHT']
# INFO:AoC:item=['JXH', 'BTG'] key='VTV' item=['JXH', 'BTG']
# INFO:AoC:item=['DKS', 'HQT'] key='TJB' item=['DKS', 'HQT']
# INFO:AoC:item=['VXF', 'HPT'] key='FCB' item=['VXF', 'HPT']
# INFO:AoC:item=['CQG', 'GRP'] key='BFH' item=['CQG', 'GRP']
# INFO:AoC:item=['TFJ', 'JDN'] key='LVK' item=['TFJ', 'JDN']
# INFO:AoC:item=['MGV', 'KBJ'] key='RNP' item=['MGV', 'KBJ']
# INFO:AoC:item=['VNP', 'PDT'] key='SJM' item=['VNP', 'PDT']
# INFO:AoC:item=['CKC', 'VKB'] key='NQP' item=['CKC', 'VKB']
# INFO:AoC:item=['MNP', 'HQS'] key='MDJ' item=['MNP', 'HQS']
# INFO:AoC:item=['VSC', 'XQN'] key='MFT' item=['VSC', 'XQN']
# INFO:AoC:item=['SSB', 'DTF'] key='LXX' item=['SSB', 'DTF']
# INFO:AoC:item=['DKL', 'XRJ'] key='JFK' item=['DKL', 'XRJ']
# INFO:AoC:item=['PSD', 'PPM'] key='LCR' item=['PSD', 'PPM']
# INFO:AoC:item=['MGV', 'KBJ'] key='SFL' item=['MGV', 'KBJ']
# INFO:AoC:item=['KKB', 'KKB'] key='DNM' item=['KKB', 'KKB']
# INFO:AoC:item=['FXK', 'PXV'] key='RJK' item=['FXK', 'PXV']
# INFO:AoC:item=['SXD', 'HNQ'] key='KBB' item=['SXD', 'HNQ']
# INFO:AoC:item=['BBJ', 'DBR'] key='MTM' item=['BBJ', 'DBR']
# INFO:AoC:item=['TVT', 'XPS'] key='NFB' item=['TVT', 'XPS']
# INFO:AoC:item=['JNQ', 'PJS'] key='XDK' item=['JNQ', 'PJS']
# INFO:AoC:item=['LTJ', 'MGN'] key='RXQ' item=['LTJ', 'MGN']
# INFO:AoC:item=['KDJ', 'XHV'] key='ZZZ' item=['KDJ', 'XHV']
# INFO:AoC:item=['CPC', 'NDH'] key='KMK' item=['CPC', 'NDH']
# INFO:AoC:item=['HHR', 'LFH'] key='FJC' item=['HHR', 'LFH']

# %%
nx.draw(G, with_labels=True)
